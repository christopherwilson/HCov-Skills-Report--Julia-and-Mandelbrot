# %%
import matplotlib.pyplot as plt
from matplotlib import cm

# %%
def gen_mandelbrot(tr : ComplexNumber, bl: ComplexNumber, res: tuple[int], N:int = 20) -> list[list]:
    """Plotting the Mandelbrot set
    
    tr = the point in the top-left of the figure
    bl = the point in the bottom-right of the figure
    res = the "resolution" of the plot (how many points in each row/column of the plot)
    N = max number of iterations
    """

    #generating points
    start = tr #start point
    diff_bounds = tr-bl
    step_re = (abs(diff_bounds.real()))/res[0]
    step_im = (abs(diff_bounds.imag()))/res[1]
    in_mandelbrot = [
        [], #stores real value of point
        []  #stores imaginary value of point
        ]
    out_mandelbrot = [
        [], # stores real value of point
        [], # stores imaginary value of point
        [] # number of iterations taken to reach 2
        ]
    for i in range(res[0]):
        for j in range(res[0]):
            c = start + CC(i*step_re, -j*step_im)
            bounded = True
            zn = 0
            for itrs in range(1, N+1):
                zn = zn^2 + c #iterating
                if zn.abs() > 2:
                    out_mandelbrot[0].append(c.real())
                    out_mandelbrot[1].append(c.imag())
                    out_mandelbrot[2].append((itrs))
                    bounded = False
                    break 
            
            if bounded:
                in_mandelbrot[0].append(c.real())
                in_mandelbrot[1].append(c.imag())
    return in_mandelbrot, out_mandelbrot

# %%
_, out_mandelbrot = gen_mandelbrot(CC(-2,1.25), CC(0.5,-1.25), (200, 200))  
plt.scatter(
    out_mandelbrot[0], 
    out_mandelbrot[1], 
    c=out_mandelbrot[2], 
    s = 1,
    cmap= "plasma"
    )
#plt.tight_layout()
ax = plt.gca()
ax.set_aspect("equal")
ax.set_facecolor("black")
ax.margins(x=0, y=0)
plt.xlabel("$\mathrm{Re}(c)$", usetex=True)
plt.ylabel("$\mathrm{Im}(c)$", usetex=True)
# Out:
# Text(0, 0.5, '$\\mathrm{Im}(c)$')

# %%
def gen_julia(tr : ComplexNumber, bl: ComplexNumber, res: tuple[int], c: ComplexNumber, N: int = 20) -> tuple[list]:
    """Plotting the Julia set generated by f(z) = z^2 + c
    
    tr = the point in the top-left of the figure
    bl = the point in the bottom-right of the figure
    res = the "resolution" of the plot (how many points in each row/column of the plot)
    c = start number
    N = max number of iterations
    """

    #generating points
    start = tr #start point
    diff_bounds = tr-bl
    step_re = (abs(diff_bounds.real()))/res[0]
    step_im = (abs(diff_bounds.imag()))/res[1]
    in_julia = [
        [], #stores real value of point
        []  #stores imaginary value of point
        ]
    out_julia = [
        [], # stores real value of point
        [], # stores imaginary value of point
        [] # number of iterations taken to reach 2
        ]
    for i in range(res[0]):
        for j in range(res[0]):
            z0 = start + CC(i*step_re, -j*step_im)
            zn = z0
            bounded = True
            for itrs in range(1, N+1):
                zn = zn^2 + c #iterating
                if zn.abs() > 2:
                    out_julia[0].append(z0.real())
                    out_julia[1].append(z0.imag())
                    out_julia[2].append((itrs))
                    bounded = False
                    break 
            
            if bounded:
                in_julia[0].append(z0.real())
                in_julia[1].append(z0.imag())
    return in_julia, out_julia

# %%
_, out_julia = gen_julia(CC(-1.5,1.25), CC(1.5,-1.25), (300, 300), CC(-0.12,0.67), N = 200)
print("plotting...")
fig = plt.scatter(
    out_julia[0], 
    out_julia[1], 
    c=out_julia[2], 
    s = 1,
    cmap= "plasma"
    )
plt.tight_layout()
ax = plt.gca()
ax.set_aspect("equal")
ax.set_facecolor("black")
ax.margins(x=0, y=0)
plt.xlabel("$\mathrm{Re}(z_0)$", usetex=True)
plt.ylabel("$\mathrm{Im}(z_0)$", usetex=True)
plt.title("$c_1 = -0.12+0.67i$")
# Out:
# plotting...
# Text(0.5, 1.0, '$c_1 = -0.12+0.7i$')

# %%
_, out_mandelbrot = gen_mandelbrot(CC(-0.4,1.15), CC(0.1,0.65), (200, 200))  
plt.scatter(
    out_mandelbrot[0], 
    out_mandelbrot[1], 
    c=out_mandelbrot[2], 
    s = 1,
    cmap= "plasma"
    )
plt.plot(
    [-0.12],
    [0.67],
    'wx'
)
plt.annotate(
    text="$c_1$",
    xy=(-0.12, 0.7),
    color="white",
    fontsize = "x-large",
    fontweight = "extra bold"
)
#plt.tight_layout()
ax = plt.gca()
ax.set_aspect("equal")
ax.set_facecolor("black")
ax.margins(x=0, y=0)
plt.xlabel("$\mathrm{Re}(c)$", usetex=True)
plt.ylabel("$\mathrm{Im}(c)$", usetex=True)
# Out:
# Text(0, 0.5, '$\\mathrm{Im}(c)$')

# %%
_, out_julia = gen_julia(CC(-1.25,1.25), CC(1.25,-1.25), (300, 300), CC(0.26,-0.5), N=200)
print("plotting...")
fig = plt.scatter(
    out_julia[0], 
    out_julia[1], 
    c=out_julia[2], 
    s = 1,
    cmap= "plasma"
    )
plt.tight_layout()
ax = plt.gca()
ax.set_aspect("equal")
ax.set_facecolor("black")
ax.margins(x=0, y=0)
plt.xlabel("$\mathrm{Re}(z_0)$", usetex=True)
plt.ylabel("$\mathrm{Im}(z_0)$", usetex=True)
plt.title("$c_2 = 0.3-0.5i$")
# Out:
# plotting...
# Text(0.5, 1.0, '$c_2 = 0.3-0.5i$')

# %%
_, out_mandelbrot = gen_mandelbrot(CC(0.2,-0.475), CC(0.45,-0.725), (200, 200), N = 200)  
plt.scatter(
    out_mandelbrot[0], 
    out_mandelbrot[1], 
    c=out_mandelbrot[2], 
    s = 1,
    cmap= "plasma"
    )
plt.plot(
    [0.26],
    [-0.5],
    'wx'
)
plt.annotate(
    text="$c_2$",
    xy=(0.3, -0.5),
    color="white",
    fontsize = "x-large",
    fontweight = "extra bold"
)
#plt.tight_layout()
ax = plt.gca()
ax.set_aspect("equal")
ax.set_facecolor("black")
ax.margins(x=0, y=0)
plt.xlabel("$\mathrm{Re}(c)$", usetex=True)
plt.ylabel("$\mathrm{Im}(c)$", usetex=True)
# Out:
# Text(0, 0.5, '$\\mathrm{Im}(c)$')

# %%
_, out_julia = gen_julia(CC(-1.25,1.25), CC(1.25,-1.25), (200, 200), CC(-0.285,-0.02))
print("plotting...")
fig = plt.scatter(
    out_julia[0], 
    out_julia[1], 
    c=out_julia[2], 
    s = 1,
    cmap= "plasma"
    )
plt.tight_layout()
ax = plt.gca()
ax.set_aspect("equal")
ax.set_facecolor("black")
ax.margins(x=0, y=0)
plt.xlabel("$\mathrm{Re}(z_0)$", usetex=True)
plt.ylabel("$\mathrm{Im}(z_0)$", usetex=True)
plt.title("$c_3 = -0.25+0i$")
# Out:
# plotting...
# Text(0.5, 1.0, '$c_3 = -0.25+0i$')

# %%
_, out_julia = gen_julia(CC(-1.25,1.25), CC(1.25,-1.25), (200, 200), CC(0.25,0.02))
print("plotting...")
fig = plt.scatter(
    out_julia[0], 
    out_julia[1], 
    c=out_julia[2], 
    s = 1,
    cmap= "plasma"
    )
plt.tight_layout()
ax = plt.gca()
ax.set_aspect("equal")
ax.set_facecolor("black")
ax.margins(x=0, y=0)
plt.xlabel("$\mathrm{Re}(z_0)$", usetex=True)
plt.ylabel("$\mathrm{Im}(z_0)$", usetex=True)
plt.title("$c_4 = 0.285+0.02i$")
# Out:
# plotting...
# Text(0.5, 1.0, '$c_5 = 0.3+0i$')

# %%
_, out_julia = gen_julia(CC(-1.25,1.25), CC(1.25,-1.25), (300, 300), CC(0.2742,0.00747), N = 100)
print("plotting...")
fig = plt.scatter(
    out_julia[0], 
    out_julia[1], 
    c=out_julia[2], 
    marker=",",
    s = 1,
    cmap= "plasma"
    )
plt.tight_layout()
ax = plt.gca()
ax.set_aspect("equal")
ax.set_facecolor("black")
ax.margins(x=0, y=0)
plt.xlabel("$\mathrm{Re}(z_0)$", usetex=True)
plt.ylabel("$\mathrm{Im}(z_0)$", usetex=True)
plt.title("$c_4 = 0.2742+0.00747i$")
# Out:
# plotting...
# Text(0.5, 1.0, '$c_4 = 0.2742+0.00747i$')

# %%
_, out_julia = gen_julia(CC(-1.25,1.25), CC(1.25,-1.25), (500, 500), CC(-0.1,0.8358))
print("plotting...")
fig = plt.scatter(
    out_julia[0], 
    out_julia[1], 
    c=out_julia[2], 
    s = 1,
    cmap= "plasma"
    )
plt.tight_layout()
ax = plt.gca()
ax.set_aspect("equal")
ax.set_facecolor("black")
ax.margins(x=0, y=0)
plt.xlabel("$\mathrm{Re}(z_0)$", usetex=True)
plt.ylabel("$\mathrm{Im}(z_0)$", usetex=True)
plt.title("$c_6 = -0.1+0.8358i$")
# Out:
# plotting...
# Text(0.5, 1.0, '$c_6 = -0.1+0.8358i$')

# %% [markdown]
# # Figure 1

# %%
n_points = 300

fig, axs = plt.subplots(3, 2, figsize=(6, 9), sharex=True, sharey=True)

_, out_julia_c1 = gen_julia(CC(-1.5,1.5), CC(1.5,-1.5), (n_points, n_points), CC(-0.12,0.67), N = 200)
print("plotting...")
axs[0][0].scatter(
    out_julia_c1[0], 
    out_julia_c1[1], 
    c=out_julia_c1[2], 
    marker=",",
    s = 1,
    cmap= "plasma"
    )
axs[0][0].set_aspect("equal")
axs[0][0].set_facecolor("black")
axs[0][0].margins(x=0, y=0)
axs[0][0].set_ylabel("$\mathrm{Im}(z_0)$", usetex=True)
axs[0][0].set_title("$c_1 = -0.12+0.67i$", usetex = True)

_, out_julia_c2 = gen_julia(CC(-1.5,1.5), CC(1.5,-1.5), (n_points, n_points), CC(0.26,-0.5), N = 200)
print("plotting...")
axs[0][1].scatter(
    out_julia_c2[0], 
    out_julia_c2[1], 
    c=out_julia_c2[2], 
    marker = ",",
    s = 1,
    cmap= "plasma"
    )
axs[0][1].set_aspect("equal")
axs[0][1].set_facecolor("black")
axs[0][1].margins(x=0, y=0)
axs[0][1].set_title("$c_2 = 0.26-0.5i$", usetex = True)

_, out_julia = gen_julia(CC(-1.5,1.5), CC(1.5,-1.5), (n_points, n_points), CC(-0.285,-0.02), N = 200)
print("plotting...")
axs[1][0].scatter(
    out_julia[0], 
    out_julia[1], 
    c=out_julia[2], 
    marker=",",
    s = 1,
    cmap= "plasma"
    )
axs[1][0].set_aspect("equal")
axs[1][0].set_facecolor("black")
axs[1][0].margins(x=0, y=0)
axs[1][0].set_ylabel("$\mathrm{Im}(z_0)$", usetex=True)
axs[1][0].set_title("$c_3 = -0.285-0.02i$", usetex = True)

_, out_julia = gen_julia(CC(-1.5,1.5), CC(1.5,-1.5), (n_points, n_points), CC(0.285,0.02), N = 200)
print("plotting...")
axs[1][1].scatter(
    out_julia[0], 
    out_julia[1], 
    c=out_julia[2], 
    marker=",",
    s = 1,
    cmap= "plasma"
    )
axs[1][1].set_aspect("equal")
axs[1][1].set_facecolor("black")
axs[1][1].margins(x=0, y=0)
axs[1][1].set_title("$c_4 = 0.285+0.02i$", usetex = True)

_, out_julia = gen_julia(CC(-1.5,1.5), CC(1.5,-1.5), (n_points, n_points), CC(0.2742,0.00747), N = 200)
print("plotting...")
axs[2][0].scatter(
    out_julia[0], 
    out_julia[1], 
    c=out_julia[2], 
    marker=",",
    s = 1,
    cmap= "plasma"
    )
axs[2][0].set_aspect("equal")
axs[2][0].set_facecolor("black")
axs[2][0].margins(x=0, y=0)
axs[2][0].set_xlabel("$\mathrm{Re}(z_0)$", usetex=True)
axs[2][0].set_ylabel("$\mathrm{Im}(z_0)$", usetex=True)
axs[2][0].set_title("$c_4 = 0.2742+0.00747i$", usetex = True)

_, out_julia = gen_julia(CC(-1.5,1.5), CC(1.5,-1.5), (n_points, n_points), CC(-0.1,0.8358), N = 200)
axs[2][1].scatter(
    out_julia[0], 
    out_julia[1], 
    c=out_julia[2], 
    marker=",",
    s = 1,
    cmap= "plasma"
    )
axs[2][1].set_aspect("equal")
axs[2][1].set_facecolor("black")
axs[2][1].margins(x=0, y=0)
axs[2][1].set_xlabel("$\mathrm{Re}(z_0)$", usetex=True)
axs[2][1].set_title("$c_6 = -0.1+0.8358i$", usetex = True)
fig.tight_layout()
fig.savefig("Julia_Sets.png")
# Out:
# plotting...
# plotting...
# plotting...
# plotting...
# plotting...

# %% [markdown]
# # Figure 2

# %%
_, out_mandelbrot = gen_mandelbrot(CC(-2,1.25), CC(0.5,-1.25), (500, 500), N = 50)  
print("plotting...")
plt.scatter(
    out_mandelbrot[0], 
    out_mandelbrot[1], 
    c=out_mandelbrot[2], 
    marker=",",
    s = 1,
    cmap= "plasma"
    )
plt.tight_layout()
ax = plt.gca()
ax.set_aspect("equal")
ax.set_facecolor("black")
ax.margins(x=0, y=0)
plt.xlabel("$\mathrm{Re}(c)$", usetex=True)
plt.ylabel("$\mathrm{Im}(c)$", usetex=True)
plt.savefig("Mandelbrot.png")
# Out:
# plotting...

# %% [markdown]
# # Figure 3

# %%
plt.scatter(
    out_mandelbrot[0], 
    out_mandelbrot[1], 
    c=out_mandelbrot[2], 
    marker=",",
    s = 1,
    cmap= "plasma"
    )
plt.plot(
    [-0.12, 0.26, -0.285, 0.285, 0.2742, -0.1],
    [0.67, -0.5, -0.02, 0.02, 0.00747, 0.8358],
    "wx"
)
plt.annotate(
    "$c_1$",
    xy = (-0.12, 0.67),
    xytext = (-0.119, 0.7-0.135),
    c = "white",
    fontsize = "xx-large",
    usetex = True
)
plt.annotate(
    "$c_2$",
    xy = (0.26,-0.5),
     xytext = (0.26-0.125,-0.5),
    c = "white",
    fontsize = "xx-large",
    usetex = True
)
plt.annotate(
    "$c_3$",
    xy = (-0.285,-0.02),
     xytext = (-0.285+0.03,-0.02-0.05),
    c = "white",
    fontsize = "xx-large",
    usetex = True
)
plt.annotate(
    "$c_4$",
    xy = (0.285, 0.02),
    xytext = (0.26-0.02, 0.065+0.01),
    c = "white",
    fontsize = "xx-large",
    usetex = True
)
plt.annotate(
    "$c_5$",
    xy = (0.2742,0.00747),
    xytext = (0.2742-0.14,0.00747-0.02),
    c = "white",
    fontsize = "xx-large",
    usetex = True
)
plt.annotate(
    "$c_6$",
    xy = (-0.1, 0.8358),
    xytext = (-0.1-0.09,0.8358-0.08),
    c = "white",
    fontsize = "xx-large",
    usetex = True
)
plt.tight_layout()
ax = plt.gca()
ax.set_aspect("equal")
ax.set_facecolor("black")
ax.margins(x=0, y=0)
plt.xlabel("$\mathrm{Re}(c)$", usetex=True)
plt.ylabel("$\mathrm{Im}(c)$", usetex=True)

plt.savefig("Mandelbrot_anno.png")

# %% [markdown]
# # Figure 4

# %%
n_points = 300

fig, axs = plt.subplots(2, 2, figsize=(6,6))

_, out_mandelbrot = gen_mandelbrot(CC(-0.325,1.15), CC(0.225,0.6), (200, 200), N=90)  
axs[0][0].scatter(
    out_mandelbrot[0], 
    out_mandelbrot[1], 
    c=out_mandelbrot[2], 
    marker=",",
    s = 1,
    cmap= "plasma"
    )
axs[0][0].plot(
    [-0.12, -0.1],
    [0.67, 0.8358],
    'wx'
)
axs[0][0].annotate(
    text="$c_1$",
    xy=(-0.12, 0.67),
    xytext=(-0.12, 0.67+0.0175),
    color="white",
    fontsize = "x-large",
    fontweight = "extra bold",
    usetex = True
)
axs[0][0].annotate(
    "$c_6$",
    xy = (-0.1, 0.8358),
    xytext = (-0.1-0.01,0.8358-0.04),
    c = "white",
    fontsize = "x-large",
    usetex = True
)
axs[0][0].set_aspect("equal")
axs[0][0].set_facecolor("black")
axs[0][0].set_xlabel("$\mathrm{Re}(c)$", usetex=True)
axs[0][0].set_ylabel("$\mathrm{Im}(c)$", usetex=True)
axs[0][0].margins(x=0, y=0)
axs[0][0].set_ylabel("$\mathrm{Im}(c)$", usetex=True)

axs[0][1].scatter(
    out_julia_c1[0], 
    out_julia_c1[1], 
    c=out_julia_c1[2], 
    marker=",",
    s = 1,
    cmap= "plasma"
    )
axs[0][1].set_aspect("equal")
axs[0][1].set_facecolor("black")
axs[0][1].margins(x=0, y=0)
axs[0][1].set_xlabel("$\mathrm{Re}(z_0)$", usetex=True)
axs[0][1].set_ylabel("$\mathrm{Im}(z_0)$", usetex=True)
axs[0][1].set_title("$c_1 = -0.12+0.7i$", usetex = True)

_, out_mandelbrot = gen_mandelbrot(CC(0.2,-0.475), CC(0.45,-0.725), (200, 200), N = 90)  
axs[1][0].scatter(
    out_mandelbrot[0], 
    out_mandelbrot[1], 
    c=out_mandelbrot[2], 
    s = 1,
    cmap= "plasma"
    )
axs[1][0].plot(
    [0.26],
    [-0.5],
    'wx'
)
axs[1][0].annotate(
    text="$c_2$",
    xy=(0.26, -0.5),
    xytext=(0.26, -0.5-0.025),
    color="white",
    fontsize = "x-large",
    fontweight = "extra bold",
    usetex = True
)

axs[1][0].set_aspect("equal")
axs[1][0].set_facecolor("black")
axs[1][0].margins(x=0, y=0)
axs[1][0].set_xlabel("$\mathrm{Re}(c)$", usetex=True)
axs[1][0].set_ylabel("$\mathrm{Im}(c)$", usetex=True)

axs[1][1].scatter(
    out_julia_c2[0], 
    out_julia_c2[1], 
    c=out_julia_c2[2], 
    s = 1,
    cmap= "plasma"
    )
axs[1][1].set_aspect("equal")
axs[1][1].set_facecolor("black")
axs[1][1].margins(x=0, y=0)
axs[1][1].set_xlabel("$\mathrm{Re}(z_0)$", usetex=True)
axs[1][1].set_ylabel("$\mathrm{Im}(z_0)$", usetex=True)
axs[1][1].set_title("$c_2 = 0.26-0.5i$", usetex = True)

fig.tight_layout()
fig.savefig("Small_Bulbs.png")
